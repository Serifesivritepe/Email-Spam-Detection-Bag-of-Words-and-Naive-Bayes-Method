# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x: 1 if x == 'spam' else 0)

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
x_train.shape
# Out:
# (4457,)

# %%
x_test.shape
# Out:
# (1115,)

# %%
type(x_train)
# Out:
# pandas.core.series.Series

# %%
x_train[:4][239]
# Out:
# "New Theory: Argument wins d SITUATION, but loses the PERSON. So dont argue with ur friends just.. . . . kick them &amp; say, I'm always correct.!"

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train[:4]
# Out:
# 239     0
# 5298    0
# 1340    0
# 3323    0
# Name: spam, dtype: int64

# %%
type(x_train.values)
# Out:
# numpy.ndarray

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

x_train_cv = v.fit_transform(x_train.values)
x_train_cv
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 59121 stored elements and shape (4457, 7731)>

# %%
x_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
x_train_cv.shape
# Out:
# (4457, 7731)

# %%
v.get_feature_names_out().shape
# Out:
# (7731,)

# %%
v.get_feature_names_out()[6847]
# Out:
# 'thought'

# %%
v.vocabulary_
# Out:
# {'new': 4754,
#  'theory': 6809,
#  'argument': 1047,
#  'wins': 7520,
#  'situation': 6177,
#  'but': 1561,
#  'loses': 4206,
#  'the': 6795,
#  'person': 5151,
#  'so': 6261,
#  'dont': 2410,
#  'argue': 1045,
#  'with': 7535,
#  'ur': 7183,
#  'friends': 3014,
#  'just': 3880,
#  'kick': 3930,
#  'them': 6803,
#  'amp': 937,
#  'say': 5903,
#  'always': 923,
#  'correct': 2003,
#  'll': 4154,
#  'hand': 3312,
#  'her': 3418,
#  'my': 4660,
#  'phone': 5178,
#  'to': 6919,
#  'chat': 1733,
#  'wit': 7534,
#  'every': 2665,
#  'monday': 4559,
#  'nxt': 4865,
#  'week': 7421,
#  'vl': 7296,
#  'be': 1260,
#  'completing': 1924,
#  'ok': 4909,
#  'darlin': 2156,
#  'supose': 6594,
#  'it': 3762,
#  'was': 7373,
#  'worry': 7589,
#  'too': 6954,
#  'much': 4628,
#  'have': 3362,
#  'do': 2373,
#  'some': 6273,
#  'film': 2849,
#  'stuff': 6522,
#  'mate': 4376,
#  'and': 949,
#  'then': 6806,
#  'babysit': 1180,
#  'again': 852,
#  'you': 7689,
#  'can': 1616,
#  'call': 1592,
#  'me': 4402,
#  'there': 6812,
#  'xx': 7640,
#  'sun': 6579,
#  'ah': 863,
#  'thk': 6837,
#  'mayb': 4394,
#  'if': 3605,
#  'dun': 2487,
#  'anythin': 988,
#  'on': 4927,
#  'book': 1416,
#  'lesson': 4083,
#  'pilates': 5203,
#  'is': 3750,
#  'at': 1105,
#  'orchard': 4968,
#  'mrt': 4608,
#  'noe': 4794,
#  'hor': 3501,
#  'take': 6668,
#  'something': 6282,
#  'for': 2947,
#  'pain': 5042,
#  'moves': 4598,
#  'however': 3529,
#  'any': 981,
#  'side': 6134,
#  'in': 3645,
#  'next': 4763,
#  '6hrs': 596,
#  'see': 5964,
#  'doctor': 2379,
#  'will': 7506,
#  'place': 5218,
#  'of': 4888,
#  'that': 6792,
#  'man': 4333,
#  'yeah': 7663,
#  'which': 7477,
#  'worse': 7590,
#  'really': 5585,
#  'need': 4723,
#  'shit': 6076,
#  'before': 1286,
#  'tomorrow': 6943,
#  'know': 3962,
#  'won': 7561,
#  'awake': 1155,
#  'like': 4109,
#  'tot': 6976,
#  'reach': 5567,
#  'liao': 4091,
#  'he': 3372,
#  'said': 5857,
#  'shirt': 6074,
#  'sure': 6604,
#  'whenever': 7468,
#  'show': 6109,
#  'fuck': 3039,
#  'up': 7169,
#  'gt': 3258,
#  'speaking': 6339,
#  'does': 2384,
#  'cash': 1663,
#  'yet': 7677,
#  'coming': 1902,
#  'home': 3478,
#  'dinner': 2329,
#  'camera': 1612,
#  'are': 1036,
#  'awarded': 1157,
#  'sipix': 6165,
#  'digital': 2317,
#  '09061221066': 184,
#  'fromm': 3032,
#  'landline': 4006,
#  'delivery': 2232,
#  'within': 7538,
#  '28': 370,
#  'days': 2174,
#  'draw': 2443,
#  'va': 7220,
#  'think': 6827,
#  'xclusive': 7634,
#  'clubsaisai': 1849,
#  '2morow': 396,
#  'soiree': 6268,
#  'speciale': 6341,
#  'zouk': 7727,
#  'nichols': 4768,
#  'from': 3031,
#  'paris': 5072,
#  'free': 2994,
#  'roses': 5801,
#  'all': 903,
#  'ladies': 3995,
#  'info': 3677,
#  '07946746291': 40,
#  '07880867867': 38,
#  'haven': 3364,
#  'found': 2974,
#  'way': 7394,
#  'get': 3127,
#  'another': 968,
#  'app': 1003,
#  'your': 7695,
#  'eh': 2550,
#  'go': 3163,
#  'net': 4739,
#  'cafe': 1582,
#  'did': 2299,
#  'job': 3837,
#  'geeee': 3110,
#  'babe': 1175,
#  'crave': 2048,
#  'min': 4478,
#  'lunch': 4260,
#  'laptop': 4015,
#  'infra': 3681,
#  'slow': 6216,
#  'lar': 4016,
#  'wan': 7355,
#  'fast': 2783,
#  'one': 4932,
#  'give': 3147,
#  'miss': 4504,
#  'number': 4853,
#  'please': 5239,
#  'advice': 831,
#  'still': 6464,
#  'not': 4826,
#  'working': 7582,
#  'this': 6836,
#  'time': 6886,
#  'also': 919,
#  'tried': 7022,
#  'adding': 807,
#  'zeros': 7722,
#  'savings': 5901,
#  'checking': 1744,
#  'lt': 4247,
#  'got': 3200,
#  'persons': 5156,
#  'story': 6486,
#  'sorry': 6308,
#  'why': 7489,
#  'ask': 1082,
#  'princess': 5399,
#  'velly': 7249,
#  'good': 3185,
#  'yes': 7674,
#  'she': 6055,
#  'fine': 2862,
#  'hear': 3384,
#  'how': 3526,
#  'dear': 2186,
#  'happy': 3337,
#  'year': 7664,
#  'oh': 4904,
#  'send': 5991,
#  'shade': 6034,
#  'has': 3348,
#  'been': 1280,
#  'wonderful': 7564,
#  'nice': 4767,
#  'off': 4890,
#  'sheffield': 6058,
#  'tom': 6937,
#  'air': 875,
#  'opinions': 4955,
#  'categories': 1674,
#  'used': 7202,
#  'measure': 4412,
#  'ethnicity': 2650,
#  'census': 1695,
#  'busy': 1560,
#  'transcribing': 7001,
#  'might': 4470,
#  'ax': 1163,
#  'well': 7438,
#  'im': 3622,
#  'okey': 4912,
#  'dokey': 2400,
#  'over': 5013,
#  'bit': 1357,
#  'sorting': 6311,
#  'out': 4996,
#  'am': 925,
#  'gas': 3092,
#  'station': 6441,
#  'evry': 2685,
#  'emotion': 2581,
#  'dsn': 2475,
#  'hav': 3359,
#  'words': 7577,
#  'wish': 7527,
#  'prayrs': 5355,
#  'smile': 6232,
#  'world': 7585,
#  'othrwise': 4991,
#  'even': 2658,
#  'drop': 2462,
#  'tear': 6719,
#  'lik': 4108,
#  'stay': 6442,
#  'morning': 4580,
#  'keep': 3911,
#  'smiling': 6236,
#  'ya': 7651,
#  'srsly': 6406,
#  'better': 1320,
#  'than': 6781,
#  'yi': 7681,
#  'tho': 6843,
#  'watching': 7384,
#  'telugu': 6740,
#  'movie': 4599,
#  'wat': 7379,
#  'abt': 758,
#  'sir': 6167,
#  'hope': 3494,
#  'had': 3293,
#  'weekend': 7423,
#  'called': 1598,
#  'let': 4085,
#  'able': 750,
#  'raise': 5536,
#  'dad': 2136,
#  'would': 7596,
#  'make': 4324,
#  'rest': 5725,
#  'available': 1142,
#  'by': 1575,
#  'mid': 4466,
#  'feb': 2803,
#  'amount': 936,
#  'quite': 5518,
#  'short': 6095,
#  'hoping': 3500,
#  'help': 3406,
#  'day': 2173,
#  'abiola': 749,
#  'pls': 5245,
#  'clarify': 1813,
#  'back': 1183,
#  'an': 945,
#  'open': 4948,
#  'return': 5740,
#  'ticket': 6873,
#  'preponed': 5371,
#  'kerala': 3919,
#  'should': 6102,
#  'use': 7201,
#  'atm': 1112,
#  'now': 4838,
#  'register': 5645,
#  'anyway': 992,
#  'when': 7467,
#  'ready': 5577,
#  'safe': 5853,
#  'trip': 7023,
#  'nigeria': 4771,
#  'happiness': 3336,
#  'very': 7257,
#  'soon': 6299,
#  'company': 1912,
#  'share': 6049,
#  'moments': 4556,
#  'erutupalam': 2639,
#  'thandiyachu': 6782,
#  'dis': 2340,
#  'pierre': 5201,
#  'cardin': 1640,
#  'looks': 4196,
#  'normal': 4819,
#  'costs': 2011,
#  '20': 340,
#  'its': 3768,
#  'sale': 5862,
#  'complete': 1921,
#  'course': 2027,
#  'what': 7460,
#  'mean': 4405,
#  'they': 6820,
#  'come': 1896,
#  'chase': 1730,
#  'or': 4963,
#  'stated': 6438,
#  'watch': 7380,
#  'as': 1074,
#  'many': 4346,
#  'movies': 4600,
#  'want': 7360,
#  'talking': 6680,
#  'bout': 1442,
#  'early': 2506,
#  'almost': 912,
#  'noon': 4809,
#  'where': 7471,
#  'bishan': 1356,
#  'nearer': 4715,
#  'no': 4791,
#  'buy': 1565,
#  'cos': 2007,
#  'gotta': 3204,
#  'park': 5074,
#  'car': 1637,
#  'aight': 872,
#  'message': 4451,
#  '08715205273': 119,
#  '500': 531,
#  'text': 6768,
#  'msgs': 4616,
#  '80488': 642,
#  'we': 7399,
#  'credit': 2056,
#  'account': 778,
#  'great': 3232,
#  'bhaji': 1330,
#  'told': 6932,
#  'kallis': 3893,
#  'best': 1315,
#  'cricketer': 2064,
#  'after': 845,
#  'sachin': 5846,
#  'tough': 6982,
#  'ill': 3618,
#  'down': 2429,
#  'done': 2408,
#  'handed': 3313,
#  'celebrations': 1693,
#  'full': 3049,
#  'swing': 6641,
#  'ard': 1035,
#  'dirty': 2339,
#  'fellow': 2816,
#  'lei': 4072,
#  'outside': 5007,
#  'wun': 7626,
#  'neva': 4748,
#  'mind': 4481,
#  'hows': 3530,
#  'favourite': 2798,
#  'today': 6923,
#  'workin': 7581,
#  'hard': 3338,
#  'couldn': 2018,
#  'sleep': 6199,
#  'last': 4022,
#  'nite': 4785,
#  'nearly': 4716,
#  'rang': 5549,
#  '30': 423,
#  'wot': 7593,
#  'people': 5132,
#  'wear': 7403,
#  'shirts': 6075,
#  'jumpers': 3875,
#  'hat': 3353,
#  'belt': 1306,
#  'cribbs': 2062,
#  'valentines': 7226,
#  'special': 6340,
#  'win': 7509,
#  '1000': 251,
#  'our': 4994,
#  'quiz': 5521,
#  'partner': 5082,
#  'lifetime': 4102,
#  '83600': 666,
#  '150p': 298,
#  'msg': 4610,
#  'rcvd': 5563,
#  'custcare': 2113,
#  '08718720201': 129,
#  'wan2': 7356,
#  'meet': 4421,
#  'greet': 3238,
#  'westlife': 7454,
#  'm8': 4285,
#  'currently': 2110,
#  'tour': 6984,
#  'unbreakable': 7117,
#  'untamed': 7166,
#  'unkempt': 7150,
#  '83049': 657,
#  'cost': 2008,
#  '50p': 537,
#  'std': 6447,
#  'jade': 3788,
#  'paul': 5104,
#  'didn': 2301,
#  'txt': 7077,
#  'remember': 5667,
#  'barmed': 1221,
#  'talk': 6676,
#  'newest': 4756,
#  'harry': 3347,
#  'potter': 5325,
#  'order': 4969,
#  'phoenix': 5177,
#  'reply': 5694,
#  'answer': 971,
#  'questions': 5513,
#  'chance': 1713,
#  'first': 2876,
#  'among': 934,
#  'readers': 5574,
#  'easy': 2515,
#  'sen': 5990,
#  'selected': 5978,
#  'means': 4409,
#  'hmmm': 3460,
#  'try': 7041,
#  'shoppin': 6091,
#  'area': 1037,
#  'forgot': 2959,
#  'name': 4679,
#  'hotel': 3514,
#  'night': 4773,
#  'spent': 6355,
#  'late': 4025,
#  'afternoon': 847,
#  'casualty': 1669,
#  'stuff42moro': 6523,
#  'includes': 3653,
#  'sheets': 6057,
#  'same': 5869,
#  'heard': 3385,
#  'about': 752,
#  'going': 3175,
#  'wildlife': 7505,
#  'tonight': 6950,
#  'want2come': 7361,
#  'that2worzels': 6793,
#  'wizzle': 7543,
#  'whatever': 7461,
#  'pa': 5032,
#  'response': 5723,
#  'powerful': 5334,
#  'weapon': 7402,
#  'occupy': 4883,
#  'others': 4988,
#  'heart': 3388,
#  'who': 7482,
#  'cares': 1649,
#  'gud': 3263,
#  'swt': 6645,
#  'dreams': 2446,
#  'care': 1642,
#  'arnt': 1057,
#  'pissed': 5211,
#  'id': 3592,
#  'love': 4223,
#  'xxxxxxxxxxxxxx': 7648,
#  'adsense': 825,
#  'approved': 1022,
#  '645': 577,
#  '12': 274,
#  'drivin': 2458,
#  'work': 7578,
#  '2morro': 397,
#  'half': 3304,
#  'term': 6752,
#  '2nite': 405,
#  'sexy': 6029,
#  'passion': 5090,
#  'b4': 1169,
#  '09099726481': 243,
#  'luv': 4265,
#  'dena': 2238,
#  'calls': 1606,
#  'minmobsmorelkpobox177hp51fl': 4489,
#  'thanx': 6789,
#  've': 7245,
#  '2geva': 386,
#  'bin': 1348,
#  'mint': 4494,
#  'baby': 1178,
#  'xxxx': 7643,
#  'rct': 5561,
#  'thnq': 6841,
#  'adrian': 822,
#  'rgds': 5751,
#  'vatian': 7241,
#  'bruv': 1519,
#  'break': 1479,
#  'rewarding': 5750,
#  'semester': 5987,
#  'jokin': 3849,
#  'only': 4937,
#  'depends': 2250,
#  'father': 2788,
#  'lor': 4202,
#  'god': 3168,
#  'gonna': 3184,
#  'google': 3195,
#  'nearby': 4714,
#  'cliffs': 1832,
#  'thasa': 6791,
#  'messed': 4455,
#  'yeh': 7666,
#  'shudvetold': 6125,
#  'urgran': 7191,
#  'neway': 4755,
#  'illspeak': 3620,
#  'u2moro': 7093,
#  'wen': 7441,
#  'asleep': 1089,
#  'lol': 4180,
#  'ouch': 4993,
#  'stayed': 6443,
#  'longer': 4188,
#  'badrith': 1189,
#  'chennai': 1755,
#  'surely': 6605,
#  'pick': 5190,
#  'us': 7197,
#  'competition': 1915,
#  'him': 3438,
#  'urgent': 7186,
#  'complimentary': 1926,
#  'eurodisinc': 2654,
#  'trav': 7009,
#  'aco': 787,
#  'entry41': 2620,
#  'claim': 1809,
#  '87121': 689,
#  '18': 313,
#  '50': 530,
#  'morefrmmob': 4577,
#  'shracomorsglsuplt': 6118,
#  '10': 249,
#  'ls1': 4243,
#  '3aj': 456,
#  'greetings': 3240,
#  'consider': 1963,
#  'yourself': 7699,
#  'excused': 2699,
#  'teaching': 6716,
#  'til': 6883,
#  'twelve': 7069,
#  'lecture': 4065,
#  'two': 7075,
#  'damn': 2141,
#  'thing': 6825,
#  'hero': 3420,
#  'leaving': 4063,
#  'qatar': 5500,
#  'tonite': 6952,
#  'apt': 1029,
#  'opportunity': 4957,
#  'touch': 6980,
#  'email': 2575,
#  'most': 4585,
#  'tiime': 6882,
#  'don': 2406,
#  'hug': 3546,
#  'into': 3723,
#  'tears': 6720,
#  'turns': 7065,
#  'randomlly': 5546,
#  '5min': 555,
#  'opening': 4951,
#  'set': 6017,
#  'details': 2273,
#  'later': 4028,
#  'planning': 5227,
#  'usually': 7212,
#  'stops': 6480,
#  'find': 2859,
#  'hella': 3403,
#  'weed': 7420,
#  'smoke': 6238,
#  'rite': 5774,
#  're': 5566,
#  'confirm': 1948,
#  'wif': 7496,
#  'forwarded': 2972,
#  '21870000': 352,
#  'hi': 3428,
#  'mailbox': 4318,
#  'messaging': 4454,
#  'sms': 6243,
#  'alert': 891,
#  '40': 475,
#  'matches': 4375,
#  '09056242159': 164,
#  'retrieve': 5739,
#  'messages': 4453,
#  'cc100p': 1683,
#  '400': 476,
#  'xmas': 7636,
#  'reward': 5749,
#  'waiting': 7339,
#  'computer': 1931,
#  'randomly': 5547,
#  'picked': 5191,
#  'loyal': 4240,
#  'mobile': 4536,
#  'customers': 2117,
#  'receive': 5603,
#  '09066380611': 226,
#  'reached': 5569,
#  'already': 916,
#  'nasty': 4693,
#  'filthyguys': 2853,
#  'fancy': 2773,
#  'rude': 5823,
#  'bitch': 1358,
#  'slo': 6213,
#  'xxx': 7642,
#  '4msgs': 517,
#  'ive': 3774,
#  'thanks': 6785,
#  'lift': 4104,
#  'genus': 3123,
#  'second': 5951,
#  'st': 6409,
#  'andre': 951,
#  'virgil': 7283,
#  'cream': 2052,
#  'neither': 4735,
#  'sterm': 6457,
#  'voice': 7300,
#  'studying': 6520,
#  'resolved': 5716,
#  'fab': 2740,
#  'hols': 3476,
#  'yup': 7715,
#  'remb': 5666,
#  'jetton': 3826,
#  'ave': 1145,
#  'tv': 7067,
#  'cinema': 1804,
#  'plus': 5248,
#  'drink': 2451,
#  'appeal': 1005,
#  'tomo': 6941,
#  'fr': 2982,
#  'thriller': 6855,
#  'director': 2336,
#  'mac': 4291,
#  'dunno': 2489,
#  'inside': 3699,
#  'ate': 1106,
#  'spageddies': 6330,
#  'gals': 3074,
#  'laughing': 4034,
#  'la': 3988,
#  'wana': 7357,
#  'pei': 5125,
#  'bf': 1327,
#  'oso': 4985,
#  'other': 4987,
#  'den': 2237,
#  'goodmorning': 3189,
#  'decimal': 2199,
#  'doing': 2397,
#  'da': 2132,
#  'intro': 3724,
#  'covers': 2033,
#  'energy': 2595,
#  'trends': 7020,
#  'pros': 5452,
#  'cons': 1960,
#  'brief': 1490,
#  'description': 2258,
#  'nuclear': 4849,
#  'fusion': 3062,
#  'history': 3446,
#  'iter': 3766,
#  'jet': 3825,
#  'pages': 5039,
#  'hey': 3425,
#  'horny': 3503,
#  'naked': 4676,
#  'hot': 3513,
#  '69698': 588,
#  'charged': 1724,
#  '150pm': 299,
#  'unsubscribe': 7164,
#  'stop': 6474,
#  'tee': 6726,
#  'hee': 3396,
#  'cheery': 1750,
#  'bye': 1577,
#  'food': 2937,
#  'tell': 6735,
#  'friend': 3013,
#  'around': 1058,
#  '4mths': 518,
#  'price': 5392,
#  'orange': 4966,
#  'line': 4123,
#  'rental': 5683,
#  'latest': 4029,
#  'phones': 5182,
#  '11mths': 272,
#  'mobilesdirect': 4538,
#  '08000938767': 49,
#  'update': 7173,
#  'or2stoptxt': 4964,
#  '09095350301': 238,
#  'girls': 3144,
#  'erotic': 2634,
#  'ecstacy': 2524,
#  '60p': 567,
#  'texts': 6778,
#  '08712460324': 107,
#  'nat': 4694,
#  'rate': 5552,
#  'jamster': 3792,
#  'crazy': 2050,
#  'frog': 3030,
#  'sound': 6317,
#  'poly': 5280,
#  'mad1': 4298,
#  'real': 5578,
#  'mad2': 4299,
#  '88888': 702,
#  'sounds': 6319,
#  'gbp': 3102,
#  '16': 308,
#  'apply': 1011,
#  '530': 548,
#  'dat': 2163,
#  'juz': 3884,
#  'haf': 3295,
#  'taught': 6698,
#  'ranjith': 5551,
#  'becaus': 1269,
#  'hes': 3423,
#  'verifying': 7254,
#  'project': 5433,
#  'prabu': 5342,
#  'mistake': 4514,
#  'cal': 1586,
#  'drpd': 2466,
#  'deeraj': 2211,
#  'deepak': 2208,
#  'hold': 3470,
#  'sch': 5916,
#  'yar': 7657,
#  'salon': 5865,
#  'boring': 1429,
#  'tel': 6730,
#  'software': 6267,
#  'eat': 2516,
#  'old': 4919,
#  'airport': 876,
#  'road': 5777,
#  '630': 575,
#  'oredi': 4972,
#  'lot': 4210,
#  'pple': 5337,
#  'crab': 2040,
#  'running': 5834,
#  'sea': 5945,
#  'shore': 6094,
#  'waves': 7393,
#  'came': 1611,
#  'cleared': 1825,
#  'footprints': 2945,
#  'asked': 1084,
#  'being': 1296,
#  'frnd': 3022,
#  'clearing': 1827,
#  'beautiful': 1266,
#  'replied': 5692,
#  'fox': 2980,
#  'following': 2930,
#  'catch': 1671,
#  'thats': 6794,
#  'frndsship': 3026,
#  'never': 4750,
#  'lets': 4086,
#  'dwn': 2497,
#  'nyt': 4869,
#  'loving': 4233,
#  'rock': 5781,
#  'those': 6844,
#  'cookies': 1990,
#  'jelly': 3813,
#  'study': 6519,
#  'wait': 7336,
#  'least': 4059,
#  'wednesday': 7417,
#  'havent': 3365,
#  'waitin': 7338,
#  'usual': 7211,
#  'put': 5493,
#  'bootydelious': 1425,
#  '32': 437,
#  'inviting': 3733,
#  '434': 487,
#  'www': 7627,
#  'ac': 763,
#  '62468': 573,
#  'stupid': 6527,
#  'wont': 7567,
#  'anything': 989,
#  'brother': 1510,
#  'spoken': 6377,
#  'opinion': 4954,
#  'sending': 5993,
#  'joy': 3859,
#  'gr8': 3212,
#  'evening': 2659,
#  'menu': 4445,
#  'connection': 1958,
#  'itself': 3769,
#  'refund': 5639,
#  'bill': 1340,
#  'important': 3636,
#  'prevent': 5387,
#  'dehydration': 2221,
#  'giving': 3150,
#  'enough': 2607,
#  'fluids': 2915,
#  'shows': 6117,
#  'spanish': 6332,
#  'holiday': 3474,
#  '09050000332': 153,
#  'rstm': 5816,
#  'sw7': 6621,
#  '3ss': 471,
#  '150ppm': 301,
#  'guaranteed': 3261,
#  'award': 1156,
#  'unclaimed': 7118,
#  '09066368327': 223,
#  'closingdate04': 1842,
#  '09': 150,
#  '02': 9,
#  'claimcode': 1810,
#  'm39m51': 4282,
#  '50pmmorefrommobile2bremoved': 540,
#  'mobypobox734ls27yf': 4543,
#  'oni': 4934,
#  'disturb': 2357,
#  '09061743811': 192,
#  'abta': 759,
#  'tenerife': 6748,
#  '5000': 532,
#  'await': 1153,
#  'collection': 1885,
#  'sae': 5851,
#  'cs': 2080,
#  'box': 1446,
#  '326': 441,
#  'cw25wx': 2127,
#  'roommate': 5796,
#  'wants': 7364,
#  'dubsack': 2478,
#  'may': 4393,
#  'plan': 5222,
#  'bringing': 1496,
#  'extra': 2732,
#  'activate': 794,
#  'replying': 5695,
#  'word': 7576,
#  'terms': 6754,
#  'conditions': 1944,
#  'visit': 7288,
#  '07781482378': 29,
#  'com': 1892,
#  'step': 6452,
#  'outta': 5011,
#  'congrats': 1953,
#  'docs': 2378,
#  'appointments': 1015,
#  'tired': 6895,
#  'shoving': 6108,
#  'ugh': 7097,
#  'body': 1404,
#  'smth': 6247,
#  'supports': 6598,
#  'ass': 1092,
#  'srt': 6407,
#  'thnk': 6840,
#  'ps3': 5464,
#  'play': 5230,
#  'through': 6857,
#  'usb': 7199,
#  'mmm': 4525,
#  'roast': 5779,
#  'few': 2823,
#  'drinks': 2454,
#  'indian': 3669,
#  'ffffffffff': 2825,
#  'alright': 917,
#  'sooner': 6300,
#  'dial': 2291,
#  'browser': 1516,
#  'surf': 6606,
#  'funk': 3057,
#  'fone': 2933,
#  'weekly': 7425,
#  'tone': 6945,
#  'tones2u': 6947,
#  'ringtones': 5768,
#  'co': 1860,
#  'uk': 7103,
#  'original': 4980,
#  'tones': 6946,
#  '3gbp': 460,
#  'network': 4745,
#  'operator': 4953,
#  'rates': 5553,
#  'gibbs': 3133,
#  'unsold': 7161,
#  'mike': 4471,
#  'hussey': 3568,
#  'ee': 2538,
#  'na': 4670,
#  'poortiyagi': 5293,
#  'odalebeku': 4886,
#  'hanumanji': 3326,
#  'hanuman': 3325,
#  'bajarangabali': 1195,
#  'maruti': 4363,
#  'pavanaputra': 5106,
#  'sankatmochan': 5873,
#  'ramaduth': 5543,
#  'mahaveer': 4314,
#  'janarige': 3795,
#  'ivatte': 3773,
#  'kalisidare': 3892,
#  'saturday': 5894,
#  'olage': 4917,
#  'ondu': 4931,
#  'news': 4759,
#  'keluviri': 3915,
#  'maretare': 4352,
#  'inde': 3663,
#  'dodda': 2382,
#  'problum': 5420,
#  'nalli': 4678,
#  'siguviri': 6143,
#  'idu': 3603,
#  ...}

# %%
x_train_np = x_train_cv.toarray()
x_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
np.where(x_train_np[0]!=0)
# Out:
# (array([ 923,  937, 1045, 1047, 1561, 2003, 2410, 3014, 3880, 3930, 4206,
#         4754, 5151, 5903, 6177, 6261, 6795, 6803, 6809, 7183, 7520, 7535]),)

# %%
x_train[:4][239]
# Out:
# "New Theory: Argument wins d SITUATION, but loses the PERSON. So dont argue with ur friends just.. . . . kick them &amp; say, I'm always correct.!"

# %%
x_train_np[0][1045]
# Out:
# np.int64(1)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB() 
model.fit(x_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
x_test_cv = v.transform(x_test)

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(x_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       967
#            1       0.99      0.91      0.95       148
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.96      0.97      1115
# weighted avg       0.99      0.99      0.99      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1])
